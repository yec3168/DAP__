# %% [markdown]
# <a href="https://colab.research.google.com/github/yec3168/DAP__/blob/main/happiness_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **World Happiness 데이터 분석**
#
#                                                                           201812033 연응찬
# 이번에 제가 조사할 데이터는 World Happiness로 전 세계의 행복도를 분석하는 것입니다.
#
# 2015년부터 2019년의 데이터를 바탕으로 하고 있으며
# 1인당 GDP, 가족, 건강(기대 수명), 자유, 관대함, 신뢰 정부 부패와 같은 요소들이 각 국가의 행복을 평가하는 데 기여하는 정도를 설명 하고 있고, 앞서 말한 요소들에 의해 각 국가의 행복지수를 평가해 점수를 매깁니다.
#
# 주된 목표로는 각 요소들이 행복 지수에 얼마나 기여하고 있는지 분석하고 그것을 시각화 하는 것을 목표로 하고 진행 하겠습니다.

# %% [markdown]
# ## **Kaggle에서 Datasheet 불러오기**

# %% [markdown]
# ▶**Kaggle** 데이터 시트를 구글 **Colab**에 불러와 사용할수 있도록 하기 위해서는  필수적인 작업이 있다.
#
#  아래 작업이 kaggle에 데이터시트를 가져와서 사용하는 방법이다.
#
#  먼저, Kaggle에 들어가 로그인을 하고, 메뉴에서 Account에 들어가 Create New API Token을 눌러 Kaggle.json파일을 다운받는다.
#
#  그리고 Colab에 아래코드를 복사해 붙여놓고 파일선택으로 아까 다운받은 Kaggle.json파일을 선택한다.

# %%
#@title 기본 제목 텍스트
# API Token 다운받기
# 다운받은 API Token 업로드 하기
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# ...
#      <input type="file" id="files-86c3ce40-cd8a-4d8d-a475-08d4da5185c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86c3ce40-cd8a-4d8d-a475-08d4da5185c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"yeonec","key":"c3d16950a73eda7d5d808e6cf6495598"}'}

# %% [markdown]
# 아래 코드는 아까 넣은 파일이 제대로 업로드 되었는지 확인하는 것이다.

# %%
ls -1ha kaggle.json
# Out:
# kaggle.json

# %% [markdown]
# 아래 작업은 Kaggle API 를 사용하기 위해서 json 파일을 ~/.kaggle로 이동 시키는 작업이다.

# %%
# json 파일 옮겨주기
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# Permission Warning 이 일어나지 않도록 
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# 내가 사용할 데이터시트를 사용하기 위한 작업이다.

# %%
# !kaggle datasets download -d unsdsn/world-happiness

# !ls
# Out:
# 401 - Unauthorized
# archive.zip  kaggle.json  sample_data

# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
#   inflating: 2015.csv
#   inflating: 2016.csv
#   inflating: 2017.csv
#   inflating: 2018.csv
#   inflating: 2019.csv

# %% [markdown]
# 압축을 풀면 아래 사진과 같은 파일이 생성된다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 데이터 읽기

# %% [markdown]
# 이번에 분석할 데이터는 전 세계의 행복도 조사이다. 2015년부터 2019년까지의 데이터가 있다.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data_2015= pd.read_csv('./2015.csv')
data_2016= pd.read_csv('./2016.csv')
data_2017= pd.read_csv('./2017.csv')
data_2018= pd.read_csv('./2018.csv')
data_2019= pd.read_csv('./2019.csv')
data_2015
# Out:
#          Country  ... Dystopia Residual
# 0    Switzerland  ...           2.51738
# 1        Iceland  ...           2.70201
# 2        Denmark  ...           2.49204
# 3         Norway  ...           2.46531
# 4         Canada  ...           2.45176
# ..           ...  ...               ...
# 153       Rwanda  ...           0.67042
# 154        Benin  ...           1.63328
# 155        Syria  ...           0.32858
# 156      Burundi  ...           1.83302
# 157         Togo  ...           1.56726
#
# [158 rows x 12 columns]

# %% [markdown]
# 2018년 데이터에는 Perceptions of corruption(Trust)에 Misiing data가 있는 것을 확인할 수 있다.

# %%
print("====================2015년======================")
print(data_2015.isnull().sum())
print("====================2016년======================")
print(data_2016.isnull().sum())
print("====================2017년======================")
print(data_2017.isnull().sum())
print("====================2018년======================")
print(data_2018.isnull().sum())
print("====================2019년======================")
print(data_2019.isnull().sum())
# Out:
# ====================2015년======================
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64
# ====================2016년======================
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# ...

# %% [markdown]
# 전 작업에서 발견한 2018년 데이터에 NAN값을 '가장 빈번하게'나온 값으로 채워넣은 작업이다.
#
# 빠르고 간단하지만, 정확하지가 않다.

# %%
from sklearn.impute import SimpleImputer

ndata_2018 = SimpleImputer(missing_values=np.nan, strategy = 'most_frequent')
ndata_2018.fit(data_2018)

ndata_2018 = pd.DataFrame(ndata_2018.transform(data_2018), columns= data_2018.columns)
ndata_2018.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# 2015년부터 2019년까지 각 column들의 명칭이 다르기 때문에 통일을 해준다.

# %%
data_2015.drop(["Region","Standard Error", "Dystopia Residual"], axis = 1, inplace=True)

data_2015 = data_2015.rename(columns={'Economy (GDP per Capita)': "GDP per Capita",
                                      'Health (Life Expectancy)': 'Health',
                                      'Trust (Government Corruption)':'Trust'})

data_2015.head(4)
# Out:
#        Country  Happiness Rank  Happiness Score  ...  Freedom    Trust  Generosity
# 0  Switzerland               1            7.587  ...  0.66557  0.41978     0.29678
# 1      Iceland               2            7.561  ...  0.62877  0.14145     0.43630
# 2      Denmark               3            7.527  ...  0.64938  0.48357     0.34139
# 3       Norway               4            7.522  ...  0.66973  0.36503     0.34699
#
# [4 rows x 9 columns]

# %%
data_2016.drop(["Region","Lower Confidence Interval", "Upper Confidence Interval","Dystopia Residual"], axis = 1, inplace=True)

data_2016 = data_2016.rename(columns={"Economy (GDP per Capita)": "GDP per Capita",
                                      "Health (Life Expectancy)": "Health",
                                      "Trust (Government Corruption)":"Trust"})

data_2016.head(4)
# Out:
#        Country  Happiness Rank  Happiness Score  ...  Freedom    Trust  Generosity
# 0      Denmark               1            7.526  ...  0.57941  0.44453     0.36171
# 1  Switzerland               2            7.509  ...  0.58557  0.41203     0.28083
# 2      Iceland               3            7.501  ...  0.56624  0.14975     0.47678
# 3       Norway               4            7.498  ...  0.59609  0.35776     0.37895
#
# [4 rows x 9 columns]

# %%
data_2017.drop(["Whisker.low","Whisker.high", "Dystopia.Residual"], axis = 1, inplace=True)

data_2017 = data_2017.rename(columns={'Happiness.Rank': 'Happiness Rank',
                                      "Happiness.Score": "Happiness Score",
                                      'Health (Life Expectancy)': 'Health',
                                      'Economy..GDP.per.Capita.':'GDP per Capita',
                                      "Health..Life.Expectancy.": "Health",
                                      "Trust..Government.Corruption.": "Trust"})


data_2017.head(4)
# Out:
#        Country  Happiness Rank  Happiness Score  ...   Freedom  Generosity     Trust
# 0       Norway               1            7.537  ...  0.635423    0.362012  0.315964
# 1      Denmark               2            7.522  ...  0.626007    0.355280  0.400770
# 2      Iceland               3            7.504  ...  0.627163    0.475540  0.153527
# 3  Switzerland               4            7.494  ...  0.620071    0.290549  0.367007
#
# [4 rows x 9 columns]

# %%
ndata_2018 = data_2018.rename(columns={"Country or region" : "Country",
                                      "Overall rank": "Happiness Rank",
                                      "Score": "Happiness Score", 
                                      "GDP per capita": "GDP per Capita",
                                      "Social support": "Family",
                                      "Healthy life expectancy": "Health",
                                      "Freedom to make life choices": "Freedom",
                                      "Perceptions of corruption": "Trust"})

ndata_2018.head(4)
# Out:
#    Happiness Rank  Country  Happiness Score  ...  Freedom  Generosity  Trust
# 0               1  Finland            7.632  ...    0.681       0.202  0.393
# 1               2   Norway            7.594  ...    0.686       0.286  0.340
# 2               3  Denmark            7.555  ...    0.683       0.284  0.408
# 3               4  Iceland            7.495  ...    0.677       0.353  0.138
#
# [4 rows x 9 columns]

# %%
data_2019 = data_2019.rename(columns={"Country or region" : "Country",
                                      "Overall rank": "Happiness Rank",
                                      "Score": "Happiness Score", 
                                      "GDP per capita": "GDP per Capita",
                                      "Social support": "Family",
                                      "Healthy life expectancy": "Health",
                                      "Freedom to make life choices": "Freedom",
                                      "Perceptions of corruption": "Trust"})

data_2019.head(4)
# Out:
#    Happiness Rank  Country  Happiness Score  ...  Freedom  Generosity  Trust
# 0               1  Finland            7.769  ...    0.596       0.153  0.393
# 1               2  Denmark            7.600  ...    0.592       0.252  0.410
# 2               3   Norway            7.554  ...    0.603       0.271  0.341
# 3               4  Iceland            7.494  ...    0.591       0.354  0.118
#
# [4 rows x 9 columns]

# %%
data_2015['Year'] = 2015
data_2016['Year'] = 2016
data_2017['Year'] = 2017
ndata_2018['Year'] = 2018
data_2019['Year'] = 2019

data1 = pd.concat([data_2015, data_2016, data_2017, ndata_2018, data_2019], ignore_index=True )
data1
# Out:
#                       Country  Happiness Rank  ...  Generosity  Year
# 0                 Switzerland               1  ...     0.29678  2015
# 1                     Iceland               2  ...     0.43630  2015
# 2                     Denmark               3  ...     0.34139  2015
# 3                      Norway               4  ...     0.34699  2015
# 4                      Canada               5  ...     0.45811  2015
# ..                        ...             ...  ...         ...   ...
# 777                    Rwanda             152  ...     0.21700  2019
# 778                  Tanzania             153  ...     0.27600  2019
# 779               Afghanistan             154  ...     0.15800  2019
# 780  Central African Republic             155  ...     0.23500  2019
# 781               South Sudan             156  ...     0.20200  2019
#
# [782 rows x 10 columns]

# %% [markdown]
# 2015년부터 2019년까지 각 나라의 Happiness Score,  GDP per Capita, Family, Health,	Freedom,	Generosity,	Trust 변화를 그려봤다.
#
# 먼저, 행복점수로 아래 그래프를보면 값이 서서히 감소하는 그래프인데, 이유가 행복점수를 내림차순으로 정렬했기 때문이다.
#
# 그외의 다른 특징들은 따로 정렬하지 않았기때문에 살짝 퍼져있는 그래프가 된다.

# %%
import plotly.io as po

fig_score1 = px.scatter(data1, x="Country", y="Happiness Score",  hover_data= ['Year'], color="Year", title = "Happiness Score 2015 ~ 2019")
fig_score1.show()
#fig_score1 - pd.read_clipboard("https://github.com/yec3168/DAP__/blob/main/plotly/family1.html")

fig_score2 = px.scatter(data1, x="Country", y="Happiness Score",  facet_col="Year", color="Year")
fig_score2.show()
#fig_score2.write_html("score2.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0d55b946-b9e4-469b-b6d7-cd075cd3622a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0d55b946-b9e4-469b-b6d7-cd075cd3622a")) {
#                     Plotly.newPlot(
#                         '0d55b946-b9e4-469b-b6d7-cd075cd3622a',
# ...

# %%
fig_gdp1 = px.scatter(data1, x="Country", y="GDP per Capita",  hover_data= ['Year'], color="Year", title = "GDP per Capita 2015 ~ 2019")
fig_gdp1.show()
#fig_gdp1.write_html("gdp1.html")

fig_gdp2 = px.scatter(data1, x="Country", y="GDP per Capita",  facet_col="Year", color="Year")
fig_gdp2.show()
#fig_gdp2.write_html("gdp2.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bc0df89d-2c98-4644-a1b1-ba6c1139591e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bc0df89d-2c98-4644-a1b1-ba6c1139591e")) {
#                     Plotly.newPlot(
#                         'bc0df89d-2c98-4644-a1b1-ba6c1139591e',
# ...

# %%
fig_family1 = px.scatter(data1, x="Country", y="Family",  hover_data= ['Year'], color="Year", title = "Family 2015 ~ 2019")
fig_family1.show()
#fig_family1.write_html("family1.html")

fig_family2 = px.scatter(data1, x="Country", y="Family",  facet_col="Year", color="Year")
fig_family2.show()
#fig_family2.write_html("family2.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="788c4b3d-2bee-4a68-a6af-8e12a1181bf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("788c4b3d-2bee-4a68-a6af-8e12a1181bf3")) {
#                     Plotly.newPlot(
#                         '788c4b3d-2bee-4a68-a6af-8e12a1181bf3',
# ...

# %%
fig_health1 = px.scatter(data1, x="Country", y="Health",  hover_data= ['Year'], color="Year", title = "Health 2015 ~ 2019")
fig_health1.show()
#fig_health1.write_html("health1.html")

fig_health2 = px.scatter(data1, x="Country", y="Health",  facet_col="Year", color="Year")
fig_health2.show()
#fig_health2.write_html("health2.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="81fcafa0-b9dd-4742-89ad-84895c14daf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("81fcafa0-b9dd-4742-89ad-84895c14daf8")) {
#                     Plotly.newPlot(
#                         '81fcafa0-b9dd-4742-89ad-84895c14daf8',
# ...

# %%
fig_freedom1 = px.scatter(data1, x="Country", y="Freedom",  hover_data= ['Year'], color="Year", title = "Freedom 2015 ~ 2019")
fig_freedom1.show()
#fig_freedom1.write_html("freedom1.html")

fig_freedom2 = px.scatter(data1, x="Country", y="Freedom",  facet_col="Year", color="Year")
fig_freedom2.show()
#fig_freedom2.write_html("freedom2.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="aa5d2781-46db-4dea-935b-020e339eefe7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa5d2781-46db-4dea-935b-020e339eefe7")) {
#                     Plotly.newPlot(
#                         'aa5d2781-46db-4dea-935b-020e339eefe7',
# ...

# %%
fig_generosity1 = px.scatter(data1, x="Country", y="Generosity",  hover_data= ['Year'], color="Year", title = "Generosity 2015 ~ 2019")
fig_generosity1.show()
#fig_generosity1.write_html("generosity1.html")

fig_generosity2 = px.scatter(data1, x="Country", y="Generosity",  facet_col="Year", color="Year")
fig_generosity2.show()
#fig_generosity2.write_html("generosity2.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="50f8a9b0-61d3-4c55-b8cb-9e0597d1279d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("50f8a9b0-61d3-4c55-b8cb-9e0597d1279d")) {
#                     Plotly.newPlot(
#                         '50f8a9b0-61d3-4c55-b8cb-9e0597d1279d',
# ...

# %%
fig_trust1 = px.scatter(data1, x="Country", y="Trust",  hover_data= ['Year'], color="Year", title = "Trust 2015 ~ 2019")
fig_trust1.show()
#fig_trust1.write_html("trust1.html")

fig_trust2 = px.scatter(data1, x="Country", y="Trust",  facet_col="Year", color="Year")
fig_trust2.show()
#fig_trust2.write_html("trust2.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7509fdd9-c38e-46a6-9b10-3329a8f0b530" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7509fdd9-c38e-46a6-9b10-3329a8f0b530")) {
#                     Plotly.newPlot(
#                         '7509fdd9-c38e-46a6-9b10-3329a8f0b530',
# ...

# %% [markdown]
# # 2019년
#
# 우리는 이번에 비교적 최신에 데이터를 가지고 분석해보려고 한다.
#
# 가지고 있는 데이터중 가장 최신 데이터는 2019년 데이터로, 이 데이터를 기반으로 분석할 것이다.

# %% [markdown]
# 시작하기에 앞서, 각 column들을 설명해 보자면
#
#
# *   Happiness Rank : 행복 순위는 전 세계에서 해당 국가의 순위를 나타내는 정수 값
# *   Country : 국가 또는 지역의 이름
# *   Happiness Score : 해당국가의 행복도 점수
# *   GDP per Capita : GDP가 행복지수 계산에 기여하는 정도.
# *   Family : 가족이 행복지수 계산에 기여하는 정도
# *   Health : 기대수명이 행복지수 계산에 기여한 정도
# *   Freedom : 자유가 행복 점수 계산에 기여한 정도
# *   Generosity : 관대함이 행복 점수 계산에 기여한 정도
# *   Trust : (정부)부패에 대한 인식이 행복지수에 기여하는 정도.
# 이다.

# %%
data_2019
# Out:
#      Happiness Rank                   Country  ...  Trust  Year
# 0                 1                   Finland  ...  0.393  2019
# 1                 2                   Denmark  ...  0.410  2019
# 2                 3                    Norway  ...  0.341  2019
# 3                 4                   Iceland  ...  0.118  2019
# 4                 5               Netherlands  ...  0.298  2019
# ..              ...                       ...  ...    ...   ...
# 151             152                    Rwanda  ...  0.411  2019
# 152             153                  Tanzania  ...  0.147  2019
# 153             154               Afghanistan  ...  0.025  2019
# 154             155  Central African Republic  ...  0.035  2019
# 155             156               South Sudan  ...  0.091  2019
#
# [156 rows x 10 columns]

# %% [markdown]
# 먼저, 각 나라의 행복 점수를 Scatter_geo 그래프로 그려봤다.
#
# 원하는 나라를 찾아 마우스를 올리면, 그 나라의 행복점수가 표시되도록 해놨다.

# %%
fig = px.scatter_geo(data_2019, locations = data_2019['Country'],
                     locationmode='country names',
                      size ="Happiness Score",
                      text = data_2019['Country'],
                      projection="orthographic",
                      color = 'Country'
                     )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f737b88c-ffc7-4aef-931e-3604d605dfbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f737b88c-ffc7-4aef-931e-3604d605dfbd")) {
#                     Plotly.newPlot(
#                         'f737b88c-ffc7-4aef-931e-3604d605dfbd',
# ...

# %% [markdown]
# 상위 10개국의 행복지수이다.

# %%
from matplotlib import text
fg = px.scatter(data_2019,
                x = data_2019.head(10)['Country'],
                y = data_2019.head(10)['Happiness Score'],
                size =  data_2019.head(10)['GDP per Capita'],
                color = data_2019.head(10)['Country']
                )
fg.show()



#plt.figure(figsize=(8, 5))
#sns.barplot(data = data_2019.head(5), y = 'Country', x = 'Happiness Score')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a4eeace5-930e-4cd2-894a-386cab2a02f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4eeace5-930e-4cd2-894a-386cab2a02f5")) {
#                     Plotly.newPlot(
#                         'a4eeace5-930e-4cd2-894a-386cab2a02f5',
# ...

# %% [markdown]
# 각 특징들간 상관관계를 분석해 보았다.
#
# 결과를 보면, Happiness Score와 가장 상관관계가 있는 특징은 **GDP per Capita**이다. 그리고 **Health**와 **Family**또한 큰 상관관계를 보이고 있다.

# %%
import seaborn as sns; sns.set_theme(color_codes=True)

plt.figure(figsize=(16, 10))

sns.heatmap(data_2019.corr(), annot= True, fmt=".2f")

plt.show()

# %% [markdown]
# 위에 상관관계 결과를 시각화하여 보여준 것이다.
#
# 결과보면 앞서 heatmap을 통해 알다 싶이 Happiness Score와 상관관계가 높았던 GDP, Family, Health는 회귀선에 밀접한 형태를 보이는 반면 상관관계가 낮았던 Generosity는 퍼져있는 형태를 보이고 있다.
#
# 지금까지의 결과로 GDP, Family, Health 이 세가지 요소가 행복지수에 크게 영향을 주고 있으며, 세 가지 요소 상승에 따라 행복지수도 따라 오른다고 생각할 수 있다..

# %%
fig, ax = plt.subplots(1, 4,figsize=(25,7))

g_gdp = sns.regplot(x="Happiness Score", y="GDP per Capita", data= data_2019, ax= ax[0],  color = 'r')

g_family = sns.regplot(x="Happiness Score", y="Family", data= data_2019, ax= ax[1],  color = 'y')

g_health = sns.regplot(x="Happiness Score", y="Health", data= data_2019, ax= ax[2],  color = 'g')

g_generosity = sns.regplot(x="Happiness Score", y="Generosity", data= data_2019, ax= ax[3],  color = 'b')

# %% [markdown]
# # 변화도
#
# 앞서진행 한 결과를 이용하여 한 국가를 선택해서 2015년부터 2019년까지 세계 행복 순위와 행복지수 등 변화를 확인해보고. GDP, Family, Health가 정말로 행복지수 상승과 연관이 있는지 확인해볼것이다.
#
# 먼저, 2019년도 세계행복지수 1위를 차지한 **Finland**를 분석할 것이기 때문에 빈 데이터프레임을 만들어준다. 그리고 2015년부터 2019년까지 Finland의 데이터를 추가한다.

# %%
finland = pd.DataFrame(columns=["Year", "Happiness Rank", "Country", "Happiness Score", "GDP per Capita", "Family", "Health", "Freedom", "Generosity", "Trust"])
finland
# Out:
# Empty DataFrame
# Columns: [Year, Happiness Rank, Country, Happiness Score, GDP per Capita, Family, Health, Freedom, Generosity, Trust]
# Index: []

# %%
finland = finland.append([data_2015[data_2015['Country'] == 'Finland'], data_2016[data_2016['Country'] == 'Finland'],
                data_2017[data_2017['Country'] == 'Finland'], ndata_2018[ndata_2018['Country'] == 'Finland'],
                data_2019[data_2019['Country'] == 'Finland']], ignore_index=True)

finland
# Out:
#    Year Happiness Rank  Country  ...   Freedom  Generosity     Trust
# 0  2015              6  Finland  ...  0.641690    0.233510  0.413720
# 1  2016              5  Finland  ...  0.571040    0.254920  0.410040
# 2  2017              5  Finland  ...  0.617951    0.245483  0.382612
# 3  2018              1  Finland  ...  0.681000    0.202000  0.393000
# 4  2019              1  Finland  ...  0.596000    0.153000  0.393000
#
# [5 rows x 10 columns]

# %% [markdown]
# 아래 plot을 보면 finland의 행복지수는 매해 성장하는 형태를 보이고 있다.

# %%
plt.figure(figsize=(10, 8))

year = ['2015', '2016', '2017', '2018', '2019']

plt.bar(year , finland['Happiness Score'])
sns.lineplot(year , finland['Happiness Score'], color='red', linewidth='3', marker='o')

plt.xlabel("Years")
plt.ylabel("Happiness Score")
plt.title("Finland Happiness Score")

plt.ylim(7, 8);

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# GDP는 2017년이후 급격히 감소했다가 다시 올라가는 형태를 보이고 있지만, Family와 Health는 2016~2017년 이후로 급격하게 증가하는 형태를 보이고 있다.

# %%
fig, ax = plt.subplots(1, 4,figsize=(25,7))


ax[0].plot(year, finland['GDP per Capita'], color='red', linewidth='3', marker='o')
ax[0].set_title("GDP per Capita", fontsize= 14)

ax[1].plot(year, finland['Family'], color='yellow', linewidth='3', marker='x')
ax[1].set_title("Family", fontsize= 14)

ax[2].plot(year, finland['Health'], color='green', linewidth='3', marker='*')
ax[2].set_title("Health", fontsize= 14)

ax[3].plot(year, finland['Generosity'], color='blue', linewidth='3', marker='^')
ax[3].set_title("Generosity",fontsize= 14)
# Out:
# Text(0.5, 1.0, 'Generosity')

# %% [markdown]
# 마지막으로, 결과를 종합해보면 행복점수는 한 가지의 특징에 영향을 받아 점수가 올라가는 것이 아닌 여러 특징들에 영향을 받아 올라가는 것이다.
#
#
# 이것으로 이번 World Happiness Score 분석을 마치도록 하겠습니다.
#
# 긴 글 읽어주셔서 감사합니다.
